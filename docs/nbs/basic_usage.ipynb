# %% [markdown]
# # Basic Usage
#
# ### Setup
# This tutorial notebook will walk you through the basic usage of the OTTER API. First make sure you followed the installation structions to install otter and the data. First the imports we will need for the notebook

# %%
import os
import otter

from astropy.coordinates import SkyCoord
from astropy import units as u

import matplotlib.pyplot as plt

# %% [markdown]
# This notebook will assume that you have set the `OTTER_ROOT` environment variable, but if you haven't all you need to do is change the following variable to the correct path.

# %%
# THIS IS WHAT YOU CHANGE IF YOU HAVE THE DATA IN A DIFFERENT PATH
otterpath = os.path.join(os.environ['OTTER_ROOT'], 'otterdb', '.otter')

# %% [markdown]
# Now that we have the `otterpath` we can initiate the otter database object and then generate a summary table of all of the data:

# %%
db = otter.Otter(otterpath)
summary = db.generate_summary_table(save=True)

summary
# Out:
# /home/noahf/anaconda3/lib/python3.11/site-packages/erfa/core.py:133: ErfaWarning: ERFA function "dtf2d" yielded 1 of "dubious year (Note 6)"
#   warn(f'ERFA function "{func_name}" yielded {wmsg}', ErfaWarning)
# /home/noahf/anaconda3/lib/python3.11/site-packages/erfa/core.py:133: ErfaWarning: ERFA function "d2dtf" yielded 1 of "dubious year (Note 5)"
#   warn(f'ERFA function "{func_name}" yielded {wmsg}', ErfaWarning)
#                 name                                             alias  \
# 0        ASASSN-20il                         [ASASSN-20il, AT 2020pom]
# 1            NGC 247                                         [NGC 247]
# 2          SDSSJ1350                                       [SDSSJ1350]
# 3          SDSSJ1201                                       [SDSSJ1201]
# 4          SDSSJ1342                                       [SDSSJ1342]
# ..               ...                                               ...
# 98         AT2019qiz           [AT2019qiz, AT2019qiz (= ZTF19abzrhgq)]
# 99   XMMSL1 J0740-85        [XMMSL1 J0740-85, XMMSL1 J074008.2-853927]
# 100      ASASSN-14ae                          [ASASSN-14ae, iPTF14aiv]
# 101         PS1-12yp  [PS1-12yp, CSS120301:133156+235405, SDSSJ133155]
# 102          J100933                                         [J100933]
#
#                 ra            dec  \
# 0      75d47m49.5s   -22d48m52.1s
# 1      11d47m09.6s     -20d45m36s
# 2    207d30m22.65s   29d16m09.71s
# 3    180d24m00.45s   30d03m05.52s
# 4     205d41m06.3s    5d30m56.14s
# ..             ...            ...
# 98    71d39m29.85s   -10d13m31.5s
# 99   115d02m02.85s  -85d39m31.25s
# 100  167d10m01.65s    34d05m52.4s
# 101  202d58m58.65s    23d54m05.7s
# 102   152d23m17.1s    23d22m55.8s
#
#                                                   refs  \
# 0                                 [ASAS-SN Supernovae]
# 1    [2017ApJ...838..149A, 2016A&A...594A..13P, 201...
# 2    [2017ApJ...838..149A, 2016A&A...594A..13P, 201...
# 3    [2017ApJ...838..149A, 2016A&A...594A..13P, 201...
# 4    [2017ApJ...838..149A, 2016A&A...594A..13P, 201...
# ..                                                 ...
# 98   [2020arXiv200602454N, 2016A&A...594A..13P, ASA...
# 99   [2017ApJ...838..149A, 2016arXiv161001788S, 201...
# 100  [2017ApJ...838..149A, 2016A&A...594A..13P, 201...
# 101  [2017ApJ...838..149A, 2016MNRAS.463..296L, 201...
# 102  [2018arXiv180205105W, 2016A&A...594A..13P, 201...
#
#               discovery_date  hasPhot  hasSpec  \
# 0    2020-07-08 04:19:12.000    False    False
# 1                        NaN    False    False
# 2                        NaN     True    False
# 3    2010-06-10 00:00:00.000     True    False
# 4    2009-05-17 00:00:00.000     True    False
# ..                       ...      ...      ...
# 98   2019-09-24 09:50:24.000    False    False
# 99   2014-04-01 00:00:00.000     True    False
# 100  2014-01-25 12:14:24.000     True    False
# 101  2012-03-01 00:00:00.000     True    False
# 102  2009-02-20 00:00:00.000     True    False
#
#                                              json_path         z
# 0    /home/noahf/astro-otter/otterdb/.otter/ASASSN-...       NaN
# 1    /home/noahf/astro-otter/otterdb/.otter/NGC-247...  0.000531
# 2    /home/noahf/astro-otter/otterdb/.otter/SDSSJ13...    0.0777
# 3    /home/noahf/astro-otter/otterdb/.otter/SDSSJ12...     0.146
# 4    /home/noahf/astro-otter/otterdb/.otter/SDSSJ13...    0.0366
# ..                                                 ...       ...
# 98   /home/noahf/astro-otter/otterdb/.otter/AT2019q...   0.01513
# 99   /home/noahf/astro-otter/otterdb/.otter/XMMSL1-...    0.0173
# 100  /home/noahf/astro-otter/otterdb/.otter/ASASSN-...  0.043671
# 101  /home/noahf/astro-otter/otterdb/.otter/PS1-12y...       NaN
# 102  /home/noahf/astro-otter/otterdb/.otter/J100933...    0.0719
#
# [103 rows x 10 columns]

# %% [markdown]
# ### Querying the OTTER Catalog
#
# Now that we have the catalog read in an initiated, we can query it for the data we want. Say we want to get all of the data associated with the TDE Sw J1644+57, we can use

# %%
swj1644_list = db.query(names='Sw J1644+57')
swj1644_list
# Out:
# [Transient(
#  	Name: Sw J1644+57,
#  	Keys: dict_keys(['classification', 'schema_version', 'name', 'coordinate', 'filter_alias', 'distance', 'date_reference', 'photometry', 'reference_alias'])
#  )]

# %% [markdown]
# Which you can see is a list of otter `Transient` objects. You can essentially treat this like a python dictionary with some benefits:
# * It has additional helpful methods to access and clean the data
# * You can use the HDF5 slash-syntax. Ex.) `swj1644['name/alias']` will give you all of the aliases from the `alias` subkey in the `name` key

# %%
swj1644 = swj1644_list[0] # just to get rid of the list

swj1644['name/alias']
# Out:
# [{'value': 'Swift J1644+57',
#   'reference': ['2017ApJ...838..149A', '2011Sci...333..203B']},
#  {'value': 'GRB 110328A', 'reference': ['2011Sci...333..203B']},
#  {'value': 'Swift J164449.3+573451', 'reference': ['2011Sci...333..203B']},
#  {'value': 'Sw J1644+57', 'reference': ['Swift']}]

# %% [markdown]
# So this TDE has multiple aliases associated with it! Let's try to query by a different one

# %%
db.query(names='GRB 110328A')[0]
# Out:
# Transient(
# 	Name: Sw J1644+57,
# 	Keys: dict_keys(['classification', 'schema_version', 'name', 'coordinate', 'filter_alias', 'distance', 'date_reference', 'photometry', 'reference_alias'])
# )

# %% [markdown]
# And look at that, it gives us the same answer! We can also query by a list of names which will give us a list of transient objects back:

# %%
db.query(names=['Sw J1644+57', '2018hyz', '2018zr'])
# Out:
# [Transient(
#  	Name: 2018zr,
#  	Keys: dict_keys(['filter_alias', 'distance', 'name', 'reference_alias', 'date_reference', 'classification', 'photometry', 'coordinate', 'schema_version'])
#  ),
#  Transient(
#  	Name: 2018hyz,
#  	Keys: dict_keys(['filter_alias', 'distance', 'name', 'reference_alias', 'date_reference', 'classification', 'photometry', 'coordinate', 'schema_version'])
#  ),
#  Transient(
#  	Name: Sw J1644+57,
#  	Keys: dict_keys(['classification', 'schema_version', 'name', 'coordinate', 'filter_alias', 'distance', 'date_reference', 'photometry', 'reference_alias'])
#  )]

# %% [markdown]
# We can also search OTTER for anything within a certain redshift range, let's look for everything between $0.1 < z <0.2$:

# %%
db.query(minz=0.1, maxz=0.2)
# Out:
# [Transient(
#  	Name: SDSSJ1201,
#  	Keys: dict_keys(['schema_version', 'name', 'coordinate', 'distance', 'classification', 'reference_alias', 'date_reference', 'photometry', 'filter_alias'])
#  ),
#  Transient(
#  	Name: J233454,
#  	Keys: dict_keys(['schema_version', 'name', 'coordinate', 'distance', 'classification', 'reference_alias'])
#  ),
#  Transient(
#  	Name: CSS100217,
#  	Keys: dict_keys(['schema_version', 'name', 'coordinate', 'distance', 'classification', 'reference_alias', 'date_reference', 'photometry', 'filter_alias'])
#  ),
#  Transient(
#  	Name: J091225,
#  	Keys: dict_keys(['schema_version', 'name', 'coordinate', 'distance', 'classification', 'reference_alias', 'date_reference', 'photometry', 'filter_alias'])
#  ),
#  Transient(
#  	Name: 2020opy,
#  	Keys: dict_keys(['filter_alias', 'name', 'reference_alias', 'date_reference', 'photometry', 'coordinate', 'schema_version', 'distance', 'classification'])
#  ),
#  Transient(
#  	Name: 3XMM J152130.7+074916,
#  	Keys: dict_keys(['schema_version', 'name', 'coordinate', 'distance', 'classification', 'reference_alias', 'date_reference', 'photometry', 'filter_alias'])
#  ),
#  Transient(
#  	Name: J145851,
#  	Keys: dict_keys(['schema_version', 'name', 'coordinate', 'distance', 'classification', 'reference_alias', 'date_reference', 'photometry', 'filter_alias'])
#  ),
#  Transient(
#  	Name: J155223,
#  	Keys: dict_keys(['schema_version', 'name', 'coordinate', 'distance', 'classification', 'reference_alias', 'date_reference', 'photometry', 'filter_alias'])
#  ),
#  Transient(
#  	Name: 2022agi,
#  	Keys: dict_keys(['filter_alias', 'name', 'reference_alias', 'date_reference', 'photometry', 'coordinate', 'schema_version', 'distance', 'classification'])
#  ),
#  Transient(
#  	Name: RX J1420+53,
#  	Keys: dict_keys(['schema_version', 'name', 'coordinate', 'distance', 'classification', 'reference_alias', 'date_reference', 'photometry', 'filter_alias'])
#  ),
#  Transient(
#  	Name: iPTF16axa,
#  	Keys: dict_keys(['schema_version', 'name', 'coordinate', 'distance', 'classification', 'reference_alias', 'date_reference', 'photometry', 'filter_alias'])
#  ),
#  Transient(
#  	Name: 2017bcc,
#  	Keys: dict_keys(['distance', 'reference_alias', 'name', 'date_reference', 'classification', 'coordinate', 'schema_version', 'filter_alias', 'photometry'])
#  ),
#  Transient(
#  	Name: PTF09djl,
#  	Keys: dict_keys(['schema_version', 'name', 'coordinate', 'distance', 'classification', 'reference_alias', 'date_reference', 'photometry', 'filter_alias'])
#  ),
#  Transient(
#  	Name: J113527,
#  	Keys: dict_keys(['schema_version', 'name', 'coordinate', 'distance', 'classification', 'reference_alias', 'date_reference', 'photometry', 'filter_alias'])
#  ),
#  Transient(
#  	Name: SDSSJ1311,
#  	Keys: dict_keys(['schema_version', 'name', 'coordinate', 'distance', 'classification', 'reference_alias', 'date_reference', 'photometry', 'filter_alias'])
#  ),
#  Transient(
#  	Name: XJ1500+0154,
#  	Keys: dict_keys(['schema_version', 'name', 'coordinate', 'distance', 'classification', 'reference_alias'])
#  ),
#  Transient(
#  	Name: J133837,
#  	Keys: dict_keys(['schema_version', 'name', 'coordinate', 'distance', 'classification', 'reference_alias', 'date_reference', 'photometry', 'filter_alias'])
#  ),
#  Transient(
#  	Name: PTF09axc,
#  	Keys: dict_keys(['schema_version', 'name', 'coordinate', 'distance', 'classification', 'reference_alias', 'date_reference', 'photometry', 'filter_alias'])
#  ),
#  Transient(
#  	Name: J030257,
#  	Keys: dict_keys(['schema_version', 'name', 'coordinate', 'distance', 'classification', 'reference_alias', 'date_reference', 'photometry', 'filter_alias'])
#  ),
#  Transient(
#  	Name: DES14C1kia,
#  	Keys: dict_keys(['schema_version', 'name', 'coordinate', 'distance', 'classification', 'reference_alias', 'date_reference', 'photometry', 'filter_alias'])
#  ),
#  Transient(
#  	Name: 2017eqx,
#  	Keys: dict_keys(['filter_alias', 'name', 'reference_alias', 'date_reference', 'photometry', 'coordinate', 'schema_version', 'distance', 'classification'])
#  ),
#  Transient(
#  	Name: XJ1231+1106,
#  	Keys: dict_keys(['schema_version', 'name', 'coordinate', 'distance', 'classification', 'reference_alias'])
#  ),
#  Transient(
#  	Name: PTF10nuj,
#  	Keys: dict_keys(['schema_version', 'name', 'coordinate', 'distance', 'classification', 'reference_alias', 'date_reference', 'photometry', 'filter_alias'])
#  ),
#  Transient(
#  	Name: Dougie,
#  	Keys: dict_keys(['schema_version', 'name', 'coordinate', 'distance', 'classification', 'reference_alias', 'date_reference', 'photometry', 'filter_alias'])
#  ),
#  Transient(
#  	Name: J141036,
#  	Keys: dict_keys(['schema_version', 'name', 'coordinate', 'distance', 'classification', 'reference_alias', 'date_reference', 'photometry', 'filter_alias'])
#  ),
#  Transient(
#  	Name: TDE1,
#  	Keys: dict_keys(['schema_version', 'name', 'coordinate', 'distance', 'classification', 'reference_alias', 'date_reference', 'photometry', 'filter_alias'])
#  ),
#  Transient(
#  	Name: J094608,
#  	Keys: dict_keys(['schema_version', 'name', 'coordinate', 'distance', 'classification', 'reference_alias'])
#  ),
#  Transient(
#  	Name: PS1-10jh,
#  	Keys: dict_keys(['schema_version', 'name', 'coordinate', 'distance', 'classification', 'reference_alias', 'date_reference', 'photometry', 'filter_alias'])
#  ),
#  Transient(
#  	Name: D23H-1,
#  	Keys: dict_keys(['schema_version', 'name', 'coordinate', 'distance', 'classification', 'reference_alias', 'date_reference', 'photometry', 'filter_alias'])
#  ),
#  Transient(
#  	Name: OGLE16aaa,
#  	Keys: dict_keys(['schema_version', 'name', 'coordinate', 'distance', 'classification', 'reference_alias', 'date_reference', 'photometry', 'filter_alias'])
#  )]

# %% [markdown]
# WOW! That's a lot of TDEs. But that's expected since many of them are discovered nearby. What if we look for everything with a redshift over 1?

# %%
db.query(minz=1)
# Out:
# [Transient(
#  	Name: 2022cmc,
#  	Keys: dict_keys(['filter_alias', 'name', 'reference_alias', 'date_reference', 'photometry', 'coordinate', 'schema_version', 'distance', 'classification'])
#  ),
#  Transient(
#  	Name: Sw J2058+05,
#  	Keys: dict_keys(['classification', 'schema_version', 'name', 'coordinate', 'filter_alias', 'distance', 'date_reference', 'photometry', 'reference_alias'])
#  )]

# %% [markdown]
# Ah makes sense, it is just those two super bright jetted TDEs!

# %% [markdown]
# # Cone Searches
#
# Moving on from general querys, we can perform cone searches on the catalog using the `otter.Otter.cone_search` method. Let's do this for objects within 15 degrees of the ecliptic pole.

# %%
# first construct a SkyCoord
coord = SkyCoord('18h00m00.0s', '+66d33m38.84s', unit=(u.hourangle, u.deg))
radius = (15*u.deg).to(u.arcsec).value # must just provide it as a float

db.cone_search(coord, radius=radius)
# Out:
# [Transient(
#  	Name: RX J1624+75,
#  	Keys: dict_keys(['schema_version', 'name', 'coordinate', 'distance', 'classification', 'reference_alias', 'date_reference', 'photometry', 'filter_alias'])
#  ),
#  Transient(
#  	Name: Sw J1644+57,
#  	Keys: dict_keys(['classification', 'schema_version', 'name', 'coordinate', 'filter_alias', 'distance', 'date_reference', 'photometry', 'reference_alias'])
#  )]

# %% [markdown]
# Which gives two results!
#
# # Photometry
#
# Finally, we can also get the cleaned up photometry associated with the transients. Let's use `['Sw J1644+57', '2018hyz', 'ASASSN-14li']` and get all of the associated photometry. This is not the fastest method but is worth the wait because you get out an astropy Table that you can then filter yourself!

# %%
phot = db.get_phot(names=['Sw J1644+57', '2018hyz', 'ASASSN-14li'])
phot
# Out:
# <Table length=542>
#     name      converted_flux   ... telescope
#    str11         float64       ...    str9
# ----------- ------------------ ... ---------
# ASASSN-14li  15.69741658188068 ...        --
# ASASSN-14li 15.797566620399987 ...        --
# ASASSN-14li 15.915797426146794 ...        --
# ASASSN-14li  16.15209376767851 ...        --
# ASASSN-14li 16.547277794462016 ...        --
# ASASSN-14li 27.400916607173308 ...     ROSAT
# ASASSN-14li  24.13537133620406 ...     Swift
# ASASSN-14li  24.12337412899964 ...     Swift
# ASASSN-14li 24.684978253500955 ...     Swift
#         ...                ... ...       ...
# Sw J1644+57 24.511055225713243 ...       XMM
# Sw J1644+57 25.231932051626835 ...       XMM
# Sw J1644+57 25.191074701952886 ...       XMM
# Sw J1644+57  26.78595875202975 ...       XMM
# Sw J1644+57  26.16900282730885 ...       XMM
# Sw J1644+57  25.80365422191501 ...       XMM
# Sw J1644+57 30.285784277703442 ...       XMM
# Sw J1644+57 30.556961925806597 ...       XMM
# Sw J1644+57 25.002340051765703 ...       XMM
# Sw J1644+57 26.319636859470897 ...       XMM

# %% [markdown]
# We can also filter it more when we call the `get_phot` method by only requesting a specific observatory type from the options of `radio`, `uvoir`, or `xray`. So, say we just want all the radio data associated with these three objects. And, since radio data is rarely reported as AB magnitudes, lets get the flux out as a flux density in units of microjanskies. We can also request that it returns a pandas DataFrame instead of an astropy Table using the `return_type='pands'` keyword.

# %%
radiophot = db.get_phot(names=['Sw J1644+57', '2018hyz', 'ASASSN-14li'], obs_type='radio', 
                        flux_unit='uJy', return_type='pandas')
radiophot
# Out:
#            name  converted_flux  converted_flux_err  converted_date  \
# 0   ASASSN-14li     1910.000000                 NaN    57124.871000
# 1   ASASSN-14li     1741.700000                 NaN    57190.830000
# 2   ASASSN-14li     1562.000000                 NaN    57229.750000
# 3   ASASSN-14li     1256.500000                 NaN    57286.514583
# 4   ASASSN-14li      873.150048                 NaN    57362.700000
# 0       2018hyz       85.000000                 NaN    58460.640000
# 1       2018hyz      900.000000                 NaN    59125.640000
# 2       2018hyz      450.000000                 NaN    59133.640000
# 3       2018hyz     1388.000000                 NaN    59400.640000
# 4       2018hyz     2939.000000                 NaN    59554.640000
# 5       2018hyz     4381.000000                 NaN    59627.640000
# 6       2018hyz     4807.000000                 NaN    59679.640000
# 7       2018hyz     7837.000000                 NaN    59724.640000
# 0   Sw J1644+57      250.000000                 0.0    55652.410000
# 1   Sw J1644+57      340.000000                 0.0    55653.300000
# 2   Sw J1644+57      340.000000                 0.0    55653.540000
# 3   Sw J1644+57      610.000000                 0.0    55654.330000
# 4   Sw J1644+57      820.000000                 0.0    55655.320000
# 5   Sw J1644+57     1480.000000                 0.0    55656.310000
# 6   Sw J1644+57     1470.000000                 0.0    55658.330000
# 7   Sw J1644+57     1800.000000                 0.0    55663.520000
# 8   Sw J1644+57     2100.000000                 0.0    55671.320000
# 9   Sw J1644+57     4620.000000                 0.0    55684.400000
# 10  Sw J1644+57     4840.000000                 0.0    55699.190000
# 11  Sw J1644+57     5860.000000                 0.0    55716.150000
# 12  Sw J1644+57     9060.000000                 0.0    55743.180000
# 13  Sw J1644+57     9100.000000                 0.0    55760.160000
# 14  Sw J1644+57     9100.000000                 0.0    55775.050000
# 15  Sw J1644+57    11710.000000                 0.0    55792.160000
# 16  Sw J1644+57    12930.000000                 0.0    55812.920000
# 17  Sw J1644+57    12830.000000                 0.0    55823.010000
# 18  Sw J1644+57    13290.000000                 0.0    55845.950000
# 19  Sw J1644+57    12430.000000                 0.0    55861.860000
# 20  Sw J1644+57    12170.000000                 0.0    55893.770000
# 21  Sw J1644+57    12050.000000                 0.0    55951.490000
# 22  Sw J1644+57    12240.000000                 0.0    56032.460000
# 23  Sw J1644+57    11120.000000                 0.0    56102.200000
# 24  Sw J1644+57     8900.000000                 0.0    56230.850000
# 25  Sw J1644+57     8240.000000                 0.0    56293.540000
# 26  Sw J1644+57     8630.000000                 0.0    56299.640000
# 27  Sw J1644+57     6230.000000                 0.0    56436.140000
# 28  Sw J1644+57     4210.000000                 0.0    56680.540000
# 29  Sw J1644+57     3520.000000                 0.0    56753.540000
# 30  Sw J1644+57     2340.000000                 0.0    57021.540000
# 31  Sw J1644+57     1470.000000                 0.0    57542.540000
#
#     converted_wave  converted_freq converted_flux_unit converted_date_unit  \
# 0     5.995849e+07             5.0                 uJy                 MJD
# 1     5.995849e+07             5.0                 uJy                 MJD
# 2     5.995849e+07             5.0                 uJy                 MJD
# 3     5.995849e+07             5.0                 uJy                 MJD
# 4     5.995849e+07             5.0                 uJy                 MJD
# 0     1.934145e+07            15.5                 uJy                 MJD
# 1     3.331027e+08             0.9                 uJy                 MJD
# 2     9.993082e+07             3.0                 uJy                 MJD
# 3     5.995849e+07             5.0                 uJy                 MJD
# 4     5.995849e+07             5.0                 uJy                 MJD
# 5     5.995849e+07             5.0                 uJy                 MJD
# 6     5.995849e+07             5.0                 uJy                 MJD
# 7     5.450772e+07             5.5                 uJy                 MJD
# 0     6.118213e+07             4.9                 uJy                 MJD
# 1     6.118213e+07             4.9                 uJy                 MJD
# 2     6.118213e+07             4.9                 uJy                 MJD
# 3     6.118213e+07             4.9                 uJy                 MJD
# 4     6.118213e+07             4.9                 uJy                 MJD
# 5     6.118213e+07             4.9                 uJy                 MJD
# 6     6.118213e+07             4.9                 uJy                 MJD
# 7     6.118213e+07             4.9                 uJy                 MJD
# 8     6.118213e+07             4.9                 uJy                 MJD
# 9     6.118213e+07             4.9                 uJy                 MJD
# 10    6.118213e+07             4.9                 uJy                 MJD
# 11    6.118213e+07             4.9                 uJy                 MJD
# 12    6.118213e+07             4.9                 uJy                 MJD
# 13    6.118213e+07             4.9                 uJy                 MJD
# 14    6.118213e+07             4.9                 uJy                 MJD
# 15    6.118213e+07             4.9                 uJy                 MJD
# 16    6.118213e+07             4.9                 uJy                 MJD
# 17    6.118213e+07             4.9                 uJy                 MJD
# 18    6.118213e+07             4.9                 uJy                 MJD
# 19    6.118213e+07             4.9                 uJy                 MJD
# 20    6.118213e+07             4.9                 uJy                 MJD
# 21    6.118213e+07             4.9                 uJy                 MJD
# 22    6.118213e+07             4.9                 uJy                 MJD
# 23    6.118213e+07             4.9                 uJy                 MJD
# 24    6.118213e+07             4.9                 uJy                 MJD
# 25    6.118213e+07             4.9                 uJy                 MJD
# 26    6.118213e+07             4.9                 uJy                 MJD
# 27    6.118213e+07             4.9                 uJy                 MJD
# 28    6.118213e+07             4.9                 uJy                 MJD
# 29    6.118213e+07             4.9                 uJy                 MJD
# 30    6.118213e+07             4.9                 uJy                 MJD
# 31    6.118213e+07             4.9                 uJy                 MJD
#
#    converted_wave_unit converted_freq_unit obs_type  upperlimit  \
# 0                   nm                 GHz    radio       False
# 1                   nm                 GHz    radio       False
# 2                   nm                 GHz    radio       False
# 3                   nm                 GHz    radio       False
# 4                   nm                 GHz    radio       False
# 0                   nm                 GHz    radio        True
# 1                   nm                 GHz    radio        True
# 2                   nm                 GHz    radio        True
# 3                   nm                 GHz    radio       False
# 4                   nm                 GHz    radio       False
# 5                   nm                 GHz    radio       False
# 6                   nm                 GHz    radio       False
# 7                   nm                 GHz    radio       False
# 0                   nm                 GHz    radio       False
# 1                   nm                 GHz    radio       False
# 2                   nm                 GHz    radio       False
# 3                   nm                 GHz    radio       False
# 4                   nm                 GHz    radio       False
# 5                   nm                 GHz    radio       False
# 6                   nm                 GHz    radio       False
# 7                   nm                 GHz    radio       False
# 8                   nm                 GHz    radio       False
# 9                   nm                 GHz    radio       False
# 10                  nm                 GHz    radio       False
# 11                  nm                 GHz    radio       False
# 12                  nm                 GHz    radio       False
# 13                  nm                 GHz    radio       False
# 14                  nm                 GHz    radio       False
# 15                  nm                 GHz    radio       False
# 16                  nm                 GHz    radio       False
# 17                  nm                 GHz    radio       False
# 18                  nm                 GHz    radio       False
# 19                  nm                 GHz    radio       False
# 20                  nm                 GHz    radio       False
# 21                  nm                 GHz    radio       False
# 22                  nm                 GHz    radio       False
# 23                  nm                 GHz    radio       False
# 24                  nm                 GHz    radio       False
# 25                  nm                 GHz    radio       False
# 26                  nm                 GHz    radio       False
# 27                  nm                 GHz    radio       False
# 28                  nm                 GHz    radio       False
# 29                  nm                 GHz    radio       False
# 30                  nm                 GHz    radio       False
# 31                  nm                 GHz    radio       False
#
#                                             reference telescope
# 0   [2016ApJ...819L..25A, 2016Sci...351...62V, 201...       NaN
# 1   [2016ApJ...819L..25A, 2016Sci...351...62V, 201...       NaN
# 2   [2016ApJ...819L..25A, 2016Sci...351...62V, 201...       NaN
# 3   [2016ApJ...819L..25A, 2016Sci...351...62V, 201...       NaN
# 4   [2016ApJ...819L..25A, 2016Sci...351...62V, 201...       NaN
# 0                               [2022ApJ...938...28C]       NaN
# 1                               [2022ApJ...938...28C]       NaN
# 2                               [2022ApJ...938...28C]       NaN
# 3                               [2022ApJ...938...28C]       NaN
# 4                               [2022ApJ...938...28C]       NaN
# 5                               [2022ApJ...938...28C]       NaN
# 6                               [2022ApJ...938...28C]       NaN
# 7                               [2022ApJ...938...28C]       NaN
# 0   [2011Natur.476..425Z, 2012ApJ...748...36B, 201...       NaN
# 1   [2011Natur.476..425Z, 2012ApJ...748...36B, 201...       NaN
# 2   [2011Natur.476..425Z, 2012ApJ...748...36B, 201...       NaN
# 3   [2011Natur.476..425Z, 2012ApJ...748...36B, 201...       NaN
# 4   [2011Natur.476..425Z, 2012ApJ...748...36B, 201...       NaN
# 5   [2011Natur.476..425Z, 2012ApJ...748...36B, 201...       NaN
# 6   [2011Natur.476..425Z, 2012ApJ...748...36B, 201...       NaN
# 7   [2011Natur.476..425Z, 2012ApJ...748...36B, 201...       NaN
# 8   [2011Natur.476..425Z, 2012ApJ...748...36B, 201...       NaN
# 9   [2011Natur.476..425Z, 2012ApJ...748...36B, 201...       NaN
# 10  [2011Natur.476..425Z, 2012ApJ...748...36B, 201...       NaN
# 11  [2011Natur.476..425Z, 2012ApJ...748...36B, 201...       NaN
# 12  [2011Natur.476..425Z, 2012ApJ...748...36B, 201...       NaN
# 13  [2011Natur.476..425Z, 2012ApJ...748...36B, 201...       NaN
# 14  [2011Natur.476..425Z, 2012ApJ...748...36B, 201...       NaN
# 15  [2011Natur.476..425Z, 2012ApJ...748...36B, 201...       NaN
# 16  [2011Natur.476..425Z, 2012ApJ...748...36B, 201...       NaN
# 17  [2011Natur.476..425Z, 2012ApJ...748...36B, 201...       NaN
# 18  [2011Natur.476..425Z, 2012ApJ...748...36B, 201...       NaN
# 19  [2011Natur.476..425Z, 2012ApJ...748...36B, 201...       NaN
# 20  [2011Natur.476..425Z, 2012ApJ...748...36B, 201...       NaN
# 21  [2011Natur.476..425Z, 2012ApJ...748...36B, 201...       NaN
# 22  [2011Natur.476..425Z, 2012ApJ...748...36B, 201...       NaN
# 23  [2011Natur.476..425Z, 2012ApJ...748...36B, 201...       NaN
# 24  [2011Natur.476..425Z, 2012ApJ...748...36B, 201...       NaN
# 25  [2011Natur.476..425Z, 2012ApJ...748...36B, 201...       NaN
# 26  [2011Natur.476..425Z, 2012ApJ...748...36B, 201...       NaN
# 27  [2011Natur.476..425Z, 2012ApJ...748...36B, 201...       NaN
# 28  [2011Natur.476..425Z, 2012ApJ...748...36B, 201...       NaN
# 29  [2011Natur.476..425Z, 2012ApJ...748...36B, 201...       NaN
# 30  [2011Natur.476..425Z, 2012ApJ...748...36B, 201...       NaN
# 31  [2011Natur.476..425Z, 2012ApJ...748...36B, 201...       NaN

# %% [markdown]
# Then we can do things like plot the light curve of all of these values!

# %%
fig, axs = plt.subplots(1,3, figsize=(18,6))

for (name, data), ax in zip(radiophot.groupby('name'), axs):
    for (f, df) in data.groupby('converted_freq'):
        fig = otter.plotter.plotter.plot_light_curve(date=df.converted_date, 
                                             flux=df.converted_flux,
                                             flux_err=df.converted_flux_err,
                                             ax=ax,
                                             fig=fig,
                                             marker='o',
                                             linestyle='none',
                                             label=f'{name}: {f}GHz')
        
    ax.legend()

# %% [markdown]
# Where the colors represent the observation frequency! Obviously these are not pubblication ready but they are at least a good way to easily visualize the data while working with it.
